# %%
import xarray as xr

data_path = "/workspace/data"
# Out:
# Running cells with '/bin/python2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python2 -m pip install ipykernel -U --user --force-reinstall'

# %%
var = "U10"
year = 2000
month = 10
ds = xr.open_dataset(f"{data_path}/{var}/{year}{month}.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/workspace/data/U10/200010.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0ee6d74a62f5> in <module>
# ...

# %%
ds.U10
# Out:
# <xarray.DataArray 'U10' (time: 744, rlat: 699, rlon: 639)>
# [332315784 values with dtype=float32]
# Coordinates:
#     lat      (rlat, rlon) float32 ...
#     lon      (rlat, rlon) float32 ...
#   * time     (time) datetime64[ns] 2000-10-01 ... 2000-10-31T23:00:00
# Dimensions without coordinates: rlat, rlon
# Attributes:
#     units:        m s-1
#     FieldType:    104
#     MemoryOrder:  XY
#     stagger:
#     long_name:    U at 10 M
