# %%
import xarray as xr
import nctoolkit as nc
data_path = "/workspace/data"
# Out:
# Please install CDO version 1.9.7 or above: https://code.mpimet.mpg.de/projects/cdo/ or https://anaconda.org/conda-forge/cdo

# %%
var = "U10"
year = 2000
month = 10
ncpath = f"{data_path}/HR/{var}/{year}{month}.nc"

ds = nc.open_data(ncpath)
oldnm = ds.contents.variable[0]
oldnm
# Out:
# 'U10'

# %%
ds.U10
# Out:
# <xarray.DataArray 'U10' (time: 744, rlat: 699, rlon: 639)>
# [332315784 values with dtype=float32]
# Coordinates:
#     lat      (rlat, rlon) float32 ...
#     lon      (rlat, rlon) float32 ...
#   * time     (time) datetime64[ns] 2000-10-01 ... 2000-10-31T23:00:00
# Dimensions without coordinates: rlat, rlon
# Attributes:
#     units:        m s-1
#     FieldType:    104
#     MemoryOrder:  XY
#     stagger:
#     long_name:    U at 10 M
